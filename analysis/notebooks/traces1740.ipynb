# %%
import ROOT
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.23/01

# %%
inFile = ROOT.TFile.Open ( "../huntingTraces/zooTraces100binsPMT1.root" ," READ ")

# %%
hist = inFile.Get ("badTrac")
badev = inFile.Get("badTrEv")
gooev = inFile.Get("gooTrac")

# %%
arr0 = []
arr1 = []

for e in range(0, hist.GetNbinsX()):
    if hist.GetBinContent(e, 1) > 0:
        arr0 = []
        for i in range( 0, hist.GetNbinsY()+1 ):
            arr0.append( hist.GetBinContent(e, i) )       
        arr1.append( arr0 )

# %%
for i in range(0, len(arr1)):
    plt.plot(arr1[i])
    
plt.xlim(1,2100)
#plt.xlabel("Bins (from 0 to 99, first bins; from 100 to 200, last bins)")
plt.xlabel("bin")

#plt.ylim(100,280)
plt.ylabel("FADC")

plt.title( "Traces for Station 1740\n("+str(len(arr1))+"/608)" )
plt.grid()
plt.savefig("../../plots/traces1740.pdf", dpi=300)

# %%
for i in range(0, len(arr1)):
    plt.plot(arr1[i])
    
plt.xlim(1,2100)
#plt.xlabel("Bins (from 0 to 99, first bins; from 100 to 200, last bins)")
plt.xlabel("bin")

plt.ylim(100,300)
plt.ylabel("FADC")

plt.title( "Traces for Station 1740\n("+str(len(arr1))+"/608)" )
plt.grid()
plt.savefig("../../plots/traces1740zoom.pdf", dpi=300)

# %%
a = []
b = []
for i in range(0, len(arr1)):
    a = []
    for j in range(0, 200):
        if j < 100:
            a.append( arr1[i][1:100] )
        else:
            a.append( arr1[i][1900:2000] )
    b.append(a)

# %%
for i in range(0, len(arr1)):
    plt.plot(b[i])
    #plt.plot(arr1[i][1:100])
    #plt.plot(arr1[i][-1:-100])
    
#plt.xlim(1,200)
#plt.xlabel("Bins (from 0 to 99, first bins; from 100 to 200, last bins)")
plt.xlabel("bin")

#plt.ylim(100,300)
plt.ylabel("FADC")

plt.title( "Traces for Station 1740\n("+str(len(arr1))+"/608)" )
plt.grid()
plt.savefig("../../plots/tracesFirstLast1740zoom.pdf", dpi=300)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-0ab5d924bee5> in <module>
#       1 for i in range(0, len(arr1)):
# ----> 2     plt.plot(b[i])
#       3     #plt.plot(arr1[i][1:100])
#       4     #plt.plot(arr1[i][-1:-100])
#       5
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# ...

# %%
arr0 = []
arr1 = []

for e in range(0, gooev.GetNbinsX()):
    if gooev.GetBinContent(e, 1) > 0:
        arr0 = []
        for i in range( 0, gooev.GetNbinsY()+1 ):
            arr0.append( gooev.GetBinContent(e, i) )
        arr1.append( arr0 )

# %%
x = []
y = []

plt.plot(arr1[12]) 
plt.plot(arr1[12] 'lr')
    
plt.xlim(1,2047)
#plt.xlabel("Bins (from 0 to 99, first bins; from 100 to 200, last bins)")
plt.xlabel("bin")

#plt.ylim(100,500)
plt.ylabel("FADC")

#plt.title( "Not Ok Traces for Station 1740\n("+str(len(arr1))+"/608)" )
plt.grid()
plt.savefig("../../plots/traceExample.pdf", dpi=300)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-adda35198410> in <module>
#       1 plt.plot(arr1[12])
# ----> 2 plt.plot(arr1[12][0:100], 'lr')
#       3
#       4 plt.xlim(1,2047)
#       5 #plt.xlabel("Bins (from 0 to 99, first bins; from 100 to 200, last bins)")
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
